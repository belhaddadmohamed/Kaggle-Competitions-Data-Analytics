# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'data\Laptop Prices Dataset\laptopPrice.csv')
df.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# ...

# %% [markdown]
# # 1. Inspect the Data

# %%
df.duplicated().sum()
# Out:
# 21

# %%
# Remove duplicates
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (802, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 802 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              802 non-null    object
#  1   processor_brand    802 non-null    object
#  2   processor_name     802 non-null    object
#  3   processor_gnrtn    802 non-null    object
#  4   ram_gb             802 non-null    object
#  5   ram_type           802 non-null    object
#  6   ssd                802 non-null    object
#  7   hdd                802 non-null    object
#  8   os                 802 non-null    object
#  9   os_bit             802 non-null    object
#  10  graphic_card_gb    802 non-null    object
#  11  weight             802 non-null    object
#  12  warranty           802 non-null    object
#  13  Touchscreen        802 non-null    object
#  14  msoffice           802 non-null    object
#  15  Price              802 non-null    int64
# ...

# %%
df.dtypes
# Out:
# brand                object
# processor_brand      object
# processor_name       object
# processor_gnrtn      object
# ram_gb               object
# ram_type             object
# ssd                  object
# hdd                  object
# os                   object
# os_bit               object
# graphic_card_gb      object
# weight               object
# warranty             object
# Touchscreen          object
# msoffice             object
# Price                 int64
# rating               object
# Number of Ratings     int64
# Number of Reviews     int64
# dtype: object

# %%
# memory_usage : a method that shows the memory usage of each column in the DataFrame
df.memory_usage()
# Out:
# Index                6416
# brand                6416
# processor_brand      6416
# processor_name       6416
# processor_gnrtn      6416
# ram_gb               6416
# ram_type             6416
# ssd                  6416
# hdd                  6416
# os                   6416
# os_bit               6416
# graphic_card_gb      6416
# weight               6416
# warranty             6416
# Touchscreen          6416
# msoffice             6416
# Price                6416
# rating               6416
# Number of Ratings    6416
# Number of Reviews    6416
# dtype: int64

# %%
df.describe(include='all')
# Out:
#        brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# count    802             802            802             802    802      802
# unique     8               3             11               8      4        6
# top     ASUS           Intel        Core i5            11th   8 GB     DDR4
# freq     243             594            284             328    404      690
# mean     NaN             NaN            NaN             NaN    NaN      NaN
# std      NaN             NaN            NaN             NaN    NaN      NaN
# min      NaN             NaN            NaN             NaN    NaN      NaN
# 25%      NaN             NaN            NaN             NaN    NaN      NaN
# 50%      NaN             NaN            NaN             NaN    NaN      NaN
# 75%      NaN             NaN            NaN             NaN    NaN      NaN
# max      NaN             NaN            NaN             NaN    NaN      NaN
#
# ...

# %%
# Data Distribution
fig, ax = plt.subplots(figsize=(10,5))
df.hist(ax=ax)
plt.show()
# Out:
# C:\Users\PC-MOH\AppData\Local\Temp\ipykernel_23416\3481956292.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df.hist(ax=ax)

# %% [markdown]
# # 2. Data Cleaning (Data Wrangling)

# %%
df['weight'].value_counts()
# Out:
# weight
# Casual        509
# ThinNlight    254
# Gaming         39
# Name: count, dtype: int64

# %%
# Rename misleading columns
df.rename(columns={'weight': 'usage_type'}, inplace=True)
df.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb usage_type     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB     Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB     Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB     Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB     Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB     Casual  No warranty
#
# ...

# %%
# Clean numeric columns (like "4 GB", "0 GB". Removing units and convert to numbers)
cols = ['ram_gb', 'ssd', 'hdd', 'graphic_card_gb']
for col in cols:
  df[col] = df[col].apply(lambda x: int(x.replace('GB', '')))

# Removing star/stars
df['rating'] = df['rating'].apply(lambda x: int(x.replace('stars', '').replace('star', '')))

# Clean CPU Generation column (Removing units)
def rename_cpu(cpu):
  if 'th' in cpu:
    return int(cpu.replace('th', ''))
  else:
    return 0
df['processor_gnrtn'] = df['processor_gnrtn'].apply(rename_cpu)

df.tail()
# Out:
#       brand processor_brand processor_name  processor_gnrtn  ram_gb ram_type  \
# 818    ASUS             AMD        Ryzen 9                0       4     DDR4
# 819    ASUS             AMD        Ryzen 9                0       4     DDR4
# 820    ASUS             AMD        Ryzen 9                0       4     DDR4
# 821    ASUS             AMD        Ryzen 9                0       4     DDR4
# 822  Lenovo             AMD        Ryzen 5               10       8     DDR4
#
#       ssd  hdd       os  os_bit  graphic_card_gb  usage_type     warranty  \
# 818  1024    0  Windows  64-bit                0      Casual       1 year
# 819  1024    0  Windows  64-bit                0      Casual       1 year
# 820  1024    0  Windows  64-bit                4      Casual       1 year
# 821  1024    0  Windows  64-bit                4      Casual       1 year
# 822   512    0      DOS  64-bit                0  ThinNlight  No warranty
#
# ...

# %%
# Convert ratings to numeric
df['Number of Ratings'] = df['Number of Ratings'].astype(int)
df['Number of Reviews'] = df['Number of Reviews'].astype(int)

# %%
# Handle missing data
df.isnull().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# usage_type           0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %% [markdown]
# # 3. Exploratory Data Analysis (EDA)

# %%
# a) Univariate Analysis (Single Variable)
sns.histplot(df['Price'], kde=True)
plt.title('Price Distribution')
plt.show()
# Out:
# c:\Users\PC-MOH\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.countplot(x='processor_brand', data=df)
plt.title('Processor Brand Count')
plt.show()

# %%
# b) Bivariate Analysis (Relationships)
sns.boxplot(x='processor_gnrtn', y='Price', data=df)
plt.show()

# %%
sns.barplot(x='ram_gb', y='Price', data=df)
plt.show()

# %%
sns.barplot(x='ssd', y='Price', data=df, hue='processor_brand')
plt.show()

# %%
# c) Correlation Analysis
numeric_df = df.select_dtypes(['int64', 'float64'])
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
df.corr(numeric_only=True)
# Out:
#                    processor_gnrtn    ram_gb       ssd       hdd  \
# processor_gnrtn           1.000000  0.290861 -0.033478  0.030126
# ram_gb                    0.290861  1.000000  0.390191 -0.173592
# ssd                      -0.033478  0.390191  1.000000 -0.595347
# hdd                       0.030126 -0.173592 -0.595347  1.000000
# graphic_card_gb          -0.029589  0.279552  0.334720 -0.063621
# Price                     0.093286  0.516454  0.628734 -0.251266
# rating                    0.041423  0.016501  0.033969 -0.072537
# Number of Ratings        -0.075336 -0.112645 -0.172900  0.120181
# Number of Reviews        -0.090634 -0.114330 -0.175805  0.127730
#
#                    graphic_card_gb     Price    rating  Number of Ratings  \
# processor_gnrtn          -0.029589  0.093286  0.041423          -0.075336
# ram_gb                    0.279552  0.516454  0.016501          -0.112645
# ssd                       0.334720  0.628734  0.033969          -0.172900
# ...

# %% [markdown]
# # 4. Feature Engineering

# %%
df['storage_total'] = df['ssd'] + df['hdd']
df['Price_DZD'] = df['Price'] * 2.8194    # 1 Indian Rupee = 2.8194 DZD (2025)
df['is_touchscreen'] = (df['Touchscreen'] == 'Yes').astype('int')

df.head()
# Out:
#     brand processor_brand processor_name  processor_gnrtn  ram_gb ram_type  \
# 0    ASUS           Intel        Core i3               10       4     DDR4
# 1  Lenovo           Intel        Core i3               10       4     DDR4
# 2  Lenovo           Intel        Core i3               10       4     DDR4
# 3    ASUS           Intel        Core i5               10       8     DDR4
# 4    ASUS           Intel   Celeron Dual                0       4     DDR4
#
#    ssd   hdd       os  os_bit  ...     warranty Touchscreen msoffice  Price  \
# 0    0  1024  Windows  64-bit  ...  No warranty          No       No  34649
# 1    0  1024  Windows  64-bit  ...  No warranty          No       No  38999
# 2    0  1024  Windows  64-bit  ...  No warranty          No       No  39999
# 3  512     0  Windows  32-bit  ...  No warranty          No       No  69990
# 4    0   512  Windows  64-bit  ...  No warranty          No       No  26990
#
# ...

# %% [markdown]
# # 5. Insights & Reporting

# %%
# Which brand offers the best price-to-rating ratio?
df['price_to_rating'] = df['Price_DZD'] / df['rating']
df.head()
# Out:
#     brand processor_brand processor_name  processor_gnrtn  ram_gb ram_type  \
# 0    ASUS           Intel        Core i3               10       4     DDR4
# 1  Lenovo           Intel        Core i3               10       4     DDR4
# 2  Lenovo           Intel        Core i3               10       4     DDR4
# 3    ASUS           Intel        Core i5               10       8     DDR4
# 4    ASUS           Intel   Celeron Dual                0       4     DDR4
#
#    ssd   hdd       os  os_bit  ...  Touchscreen msoffice  Price rating  \
# 0    0  1024  Windows  64-bit  ...           No       No  34649      2
# 1    0  1024  Windows  64-bit  ...           No       No  38999      3
# 2    0  1024  Windows  64-bit  ...           No       No  39999      3
# 3  512     0  Windows  32-bit  ...           No       No  69990      3
# 4    0   512  Windows  64-bit  ...           No       No  26990      3
#
#   Number of Ratings  Number of Reviews  storage_total    Price_DZD  \
# ...

# %%
df.loc[df['price_to_rating'].idxmin()]
# Out:
# brand                      Lenovo
# processor_brand             Intel
# processor_name       Celeron Dual
# processor_gnrtn                 0
# ram_gb                          4
# ram_type                   LPDDR4
# ssd                             0
# hdd                           512
# os                        Windows
# os_bit                     32-bit
# graphic_card_gb                 0
# usage_type                 Casual
# warranty              No warranty
# Touchscreen                    No
# msoffice                       No
# Price                       16990
# rating                          3
# Number of Ratings             414
# Number of Reviews              54
# storage_total                 512
# Price_DZD               47901.606
# is_touchscreen                  0
# price_to_rating         15967.202
# Name: 194, dtype: object

# %%
# Does SSD presence significantly impact price?
df[['ssd', 'Price_DZD']].corr()   # 60%
# Out:
#                 ssd  Price_DZD
# ssd        1.000000   0.628734
# Price_DZD  0.628734   1.000000

# %%
# How does RAM affect rating or price?
df[['ram_gb', 'Price_DZD']].corr()  # 51%
# Out:
#              ram_gb  Price_DZD
# ram_gb     1.000000   0.516454
# Price_DZD  0.516454   1.000000

# %%
# 📊 Average Price by Brand: Which brands are premium vs. budget-friendly?
brands_df = df.groupby(by='brand', as_index=False)['Price_DZD'].mean().sort_values('Price_DZD')
brands_df
# Out:
#     brand      Price_DZD
# 2   Avita  158863.322100
# 3    DELL  171388.374145
# 7    acer  204181.058565
# 5  Lenovo  205591.235375
# 4      HP  207621.383043
# 1    ASUS  223933.722412
# 6     MSI  278311.488588
# 0   APPLE  442875.029478

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.barplot(data=brands_df, x='brand', y='Price_DZD', ax=ax)
plt.title('Brands by Mean Prices')
plt.tight_layout()
plt.show()

# %%
# 📉 Price vs. CPU Generation: Does newer generation significantly increase price?
cpu_gen_df = df.groupby(by='processor_gnrtn', as_index=False)['Price_DZD'].mean().sort_values(by='Price_DZD', ascending=False)
cpu_gen_df
# Out:
#    processor_gnrtn      Price_DZD
# 7               12  676627.806000
# 5               10  250719.715845
# 4                9  247801.765000
# 3                8  243977.262326
# 6               11  203181.823125
# 0                0  195050.799391
# 2                7  154444.718143
# 1                4  147990.306000

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.lineplot(data=cpu_gen_df, x='processor_gnrtn', y='Price_DZD', markers='o', ax=ax)
plt.title('CPU Generations by Mean Prices')
plt.tight_layout()
plt.show()
# Out:
# c:\Users\PC-MOH\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\PC-MOH\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
1 - df[(df['hdd'] > 0) & (df['ssd'] <= 0)]['Price_DZD'].mean()  /  df[(df['ssd'] == 512)]['Price_DZD'].mean()
# Out:
# 0.29521748289491

# %% [markdown]
# "Laptops with 512GB SSD are on average `30%` more expensive than those with HDD only"

# %%
# 🔍 Top 5 Most Common Configurations
df[['processor_name', 'processor_gnrtn', 'graphic_card_gb', 'ram_gb', 'ssd']].value_counts()[:5]
# Out:
# processor_name  processor_gnrtn  graphic_card_gb  ram_gb  ssd
# Core i5         11               0                8       512    75
# Core i3         11               0                8       256    26
#                                                   4       256    23
#                                                   8       512    22
# Core i5         10               0                8       512    21
# Name: count, dtype: int64

# %% [markdown]
# `Corei5 | 11th | Integrated_Gpu | 8Gb | 512Gb` Is the most common configuration

# %%
# 🖥️ Touchscreen Impact: Do touchscreen laptops command a premium?
touchscreen_prices_df = df.groupby(['processor_name', 'processor_gnrtn', 'Touchscreen'], as_index=False)['Price_DZD'].mean()

# Take only the group ('processor_name', 'processor_gnrtn') that have both (No/Yes) to make a comparision
indexes = []
for index in touchscreen_prices_df.index:
  item = touchscreen_prices_df.iloc[index]
  if touchscreen_prices_df.loc[(touchscreen_prices_df['processor_name']==item['processor_name']) & (touchscreen_prices_df['processor_gnrtn']==item['processor_gnrtn']), ['processor_gnrtn', 'Touchscreen']].shape[0] < 2:
    indexes.append(index)
touchscreen_prices_df.drop(labels=indexes, inplace=True)
touchscreen_prices_df
# Out:
#    processor_name  processor_gnrtn Touchscreen      Price_DZD
# 4         Core i3               11          No  121359.782190
# 5         Core i3               11         Yes  163265.046273
# 9         Core i5                8          No  212404.753336
# 10        Core i5                8         Yes  308143.503600
# 12        Core i5               10          No  242720.575191
# 13        Core i5               10         Yes  343286.760720
# 14        Core i5               11          No  187549.327396
# 15        Core i5               11         Yes  242278.531031
# 18        Core i7               10          No  368945.517352
# 19        Core i7               10         Yes  517032.285720
# 20        Core i7               11          No  307774.643561
# 21        Core i7               11         Yes  326654.932160
# 23        Core i9               10          No  749954.761200
# 24        Core i9               10         Yes  761209.806000
# ...

# %%
1 - touchscreen_prices_df[touchscreen_prices_df['Touchscreen']=='No']['Price_DZD'].mean() / touchscreen_prices_df[touchscreen_prices_df['Touchscreen']=='Yes']['Price_DZD'].mean()
# Out:
# 0.17194549836070772

# %% [markdown]
# "Touchscreen laptops are on average `17%` more expensive, with similar core specs."

# %%
gpu_prices_df = df.groupby('graphic_card_gb', as_index=False)['Price_DZD'].mean().sort_values('Price_DZD', ascending=False)
sns.lineplot(gpu_prices_df, x='graphic_card_gb', y='Price_DZD')
# Out:
# c:\Users\PC-MOH\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\PC-MOH\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='graphic_card_gb', ylabel='Price_DZD'>
