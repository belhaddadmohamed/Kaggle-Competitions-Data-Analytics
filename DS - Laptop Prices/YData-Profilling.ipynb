# %%
import pandas as pd
from ydata_profiling import ProfileReport

df = pd.read_csv(r'D:\Projects\Data Science\DS - Data Analysis\DS - Laptop Prices\data\Laptop Prices Dataset\laptopPrice.csv')
profile = ProfileReport(df, title="Profiling Report")

# %%
profile.to_file('output.html')
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 164.92it/s]
